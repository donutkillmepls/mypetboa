# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
df = pd.read_csv('https://query.data.world/s/xvulmqmi6eb66adhe6pwa2peyegqpk')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#    Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0  Confirmed                        NaN      0           0   2/3/2020
# 1     Deaths                        NaN      0           0   3/1/2020
# 2  Confirmed                        NaN     23           0  4/21/2020
# 3     Deaths                        NaN      0           0  2/11/2020
# 4  Confirmed                        NaN      0           0   2/6/2020
# 5  Confirmed                        NaN      1           0  3/18/2020
# 6     Deaths                        NaN      0           0   5/2/2020
# 7  Confirmed                        NaN      1           0  3/19/2020
# 8     Deaths                        NaN      5           1  4/13/2020
# 9  Confirmed                        NaN     18           0  4/29/2020
#
#                                     Combined_Key            Country_Region  \
# 0                                    Switzerland               Switzerland
# ...

# %%
df.columns
# Out:
# Index(['Case_Type', 'People_Total_Tested_Count', 'Cases', 'Difference', 'Date',
#        'Combined_Key', 'Country_Region', 'Province_State', 'Admin2', 'iso2',
#        'iso3', 'FIPS', 'Lat', 'Long', 'Population_Count',
#        'People_Hospitalized_Cumulative_Count', 'Data_Source',
#        'Prep_Flow_Runtime'],
#       dtype='object')

# %%
df.isna()
# Out:
#         Case_Type  People_Total_Tested_Count  Cases  Difference   Date  \
# 0           False                       True  False       False  False
# 1           False                       True  False       False  False
# 2           False                       True  False       False  False
# 3           False                       True  False       False  False
# 4           False                       True  False       False  False
# ...           ...                        ...    ...         ...    ...
# 718075      False                       True  False       False  False
# 718076      False                       True  False       False  False
# 718077      False                       True  False       False  False
# 718078      False                       True  False       False  False
# 718079      False                       True  False       False  False
#
#         Combined_Key  Country_Region  Province_State  Admin2   iso2   iso3  \
# ...

# %%
dfg=df.groupby("Case_Type")
dfg.describe()
# Out:
#           People_Total_Tested_Count                                            \
#                               count         mean            std  min      25%
# Case_Type
# Confirmed                    1176.0  81998.64881  120082.678301  3.0  17375.0
# Deaths                       1176.0  81998.64881  120082.678301  3.0  17375.0
#
#                                            Cases              ...  \
#                50%       75%       max     count        mean  ...
# Case_Type                                                     ...
# Confirmed  44501.0  93964.75  959071.0  359040.0  223.902376  ...
# Deaths     44501.0  93964.75  959071.0  359040.0   14.535935  ...
#
#           Population_Count               People_Hospitalized_Cumulative_Count  \
#                        75%           max                                count
# Case_Type
# Confirmed          97947.0  1.380004e+09                               1176.0
# ...

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=df['Date'],y=df['Cases'],hue=df['Case_Type'])

# %%
country=df.groupby(['Country_Region'])

# %%
country.groups
# Out:
# {'Afghanistan': Int64Index([    64,    175,    497,    684,    819,    917,   1101,   1826,
#                1876,   2124,
#              ...
#               50027,  99692, 100314, 100386, 100867, 101070, 101099, 101549,
#              673143, 717870],
#             dtype='int64', length=204),
#  'Albania': Int64Index([   127,    344,   1987,   2011,   2206,   2585,   2628,   2646,
#                2660,   2748,
#              ...
#               49495,  49660,  99502,  99892, 100513, 100521, 101141, 101365,
#              661531, 696437],
#             dtype='int64', length=204),
#  'Algeria': Int64Index([   925,   1164,   1878,   1946,   2029,   2653,   2738,   2959,
#                2961,   3448,
#              ...
#              100210, 100251, 100614, 100822, 101154, 101345, 101609, 101699,
#              690924, 691135],
#             dtype='int64', length=204),
#  'Andorra': Int64Index([   126,    541,    551,    960,   1413,   1489,   1679,   2037,
# ...

# %%
ind=country.get_group('India')

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x=ind.Date, y=ind.Cases,hue=ind.Case_Type)

# %%
df.dtypes
# Out:
# Case_Type                                object
# People_Total_Tested_Count               float64
# Cases                                     int64
# Difference                                int64
# Date                                     object
# Combined_Key                             object
# Country_Region                           object
# Province_State                           object
# Admin2                                   object
# iso2                                     object
# iso3                                     object
# FIPS                                    float64
# Lat                                     float64
# Long                                    float64
# Population_Count                        float64
# People_Hospitalized_Cumulative_Count    float64
# Data_Source                              object
# Prep_Flow_Runtime                        object
# dtype: object

# %%
dated=df.groupby('Date')
dated.dtypes
# Out:
#           Case_Type People_Total_Tested_Count  Cases Difference Combined_Key  \
# Date
# 1/22/2020    object                   float64  int64      int64       object
# 1/23/2020    object                   float64  int64      int64       object
# 1/24/2020    object                   float64  int64      int64       object
# 1/25/2020    object                   float64  int64      int64       object
# 1/26/2020    object                   float64  int64      int64       object
# ...             ...                       ...    ...        ...          ...
# 4/7/2020     object                   float64  int64      int64       object
# 4/8/2020     object                   float64  int64      int64       object
# 4/9/2020     object                   float64  int64      int64       object
# 5/1/2020     object                   float64  int64      int64       object
# 5/2/2020     object                   float64  int64      int64       object
#
# ...

# %%
latest=dated.get_group('5/2/2020')

# %%
country.describe()
# Out:
#                    People_Total_Tested_Count                               \
#                                        count mean std min 25% 50% 75% max
# Country_Region
# Afghanistan                              0.0  NaN NaN NaN NaN NaN NaN NaN
# Albania                                  0.0  NaN NaN NaN NaN NaN NaN NaN
# Algeria                                  0.0  NaN NaN NaN NaN NaN NaN NaN
# Andorra                                  0.0  NaN NaN NaN NaN NaN NaN NaN
# Angola                                   0.0  NaN NaN NaN NaN NaN NaN NaN
# ...                                      ...  ...  ..  ..  ..  ..  ..  ..
# West Bank and Gaza                       0.0  NaN NaN NaN NaN NaN NaN NaN
# Western Sahara                           0.0  NaN NaN NaN NaN NaN NaN NaN
# Yemen                                    0.0  NaN NaN NaN NaN NaN NaN NaN
# Zambia                                   0.0  NaN NaN NaN NaN NaN NaN NaN
# ...
